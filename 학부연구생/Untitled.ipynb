# %%
# 사용할 패키지를 import합니다
import sys
print('python', sys.version)

import numpy as np
print('numpy', np.__version__)

import pandas as pd
print('pandas', pd.__version__)

import matplotlib as mpl
print('matplotlib', mpl.__version__)

import matplotlib.pyplot as plt

import seaborn as sns
print('pandas', sns.__version__)

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# # 경고 메시지는 출력되지 않게 합니다.
# import warnings
# warnings.filterwarnings("ignore")
# Out:
# python 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# numpy 1.20.1
# pandas 1.2.4
# matplotlib 3.3.4
# pandas 0.11.1

# %%
df1=pd.read_csv('LABEVENTS_small.csv', index_col=0)
df1
# Out:
#           subject_id   hadm_id  itemid  valuenum valueuom      flag
# row_id
# 6245198        10006  142345.0   50813      4.40   mmol/L  abnormal
# 6245199        10006  142345.0   50861      9.00     IU/L       NaN
# 6245200        10006  142345.0   50862      3.40     g/dL       NaN
# 6245201        10006  142345.0   50863    167.00     IU/L  abnormal
# 6245202        10006  142345.0   50868     20.00    mEq/L       NaN
# ...              ...       ...     ...       ...      ...       ...
# 20452679       44228  103379.0   51250     88.00       fL       NaN
# 20452680       44228  103379.0   51265    595.00     K/uL  abnormal
# 20452681       44228  103379.0   51277     14.50        %       NaN
# 20452682       44228  103379.0   51279      2.76     m/uL  abnormal
# 20452683       44228  103379.0   51301     16.90     K/uL  abnormal
#
# [61812 rows x 6 columns]

# %%
df1['flag']=='abnormal'
# Out:
# row_id
# 6245198      True
# 6245199     False
# 6245200     False
# 6245201      True
# 6245202     False
#             ...
# 20452679    False
# 20452680     True
# 20452681    False
# 20452682     True
# 20452683     True
# Name: flag, Length: 61812, dtype: bool

# %%
A=df1['itemid']==50882
B=df1((df1[A]) & (df1['flag']=='abnormal'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-af8e69a61011> in <module>
#       1 A=df1['itemid']==50882
# ----> 2 B=df1((df1[A]) & (df1['flag']=='abnormal'))
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      57     @unpack_zerodim_and_defer("__and__")
#      58     def __and__(self, other):
# ---> 59         return self._logical_method(other, operator.and_)
#      60
#      61     @unpack_zerodim_and_defer("__rand__")
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    5978         axis = 1  # only relevant for Series other case
#    5979
# -> 5980         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    5981
#    5982         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     285                 )
#     286
# --> 287         left, right = left.align(
#     288             right, join="outer", axis=axis, level=level, copy=False
#     289         )
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    4100         broadcast_axis=None,
#    4101     ) -> DataFrame:
# -> 4102         return super().align(
#    4103             other,
#    4104             join=join,
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8823             )
#    8824         elif isinstance(other, ABCSeries):
# -> 8825             return self._align_series(
#    8826                 other,
#    8827                 join=join,
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8962
#    8963                 if lidx is not None:
# -> 8964                     fdata = fdata.reindex_indexer(join_index, lidx, axis=0)
#    8965             else:
#    8966                 raise ValueError("Must specify axis=0 or 1")
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#    1305
#    1306         if axis == 0:
# -> 1307             new_blocks = self._slice_take_blocks_ax0(
#    1308                 indexer, fill_value=fill_value, only_slice=only_slice
#    1309             )
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#    1402
#    1403                 blocks.append(
# -> 1404                     self._make_na_block(placement=mgr_locs, fill_value=fill_value)
#    1405                 )
#    1406             else:
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _make_na_block(self, placement, fill_value)
#    1448
#    1449         dtype, fill_value = infer_dtype_from_scalar(fill_value)
# -> 1450         block_values = np.empty(block_shape, dtype=dtype)
#    1451         block_values.fill(fill_value)
#    1452         return make_block(block_values, placement=placement, ndim=block_values.ndim)
#
# MemoryError: Unable to allocate 809. MiB for an array with shape (61812, 1716) and data type float64
